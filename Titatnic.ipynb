# %%
import pandas as pd 
import numpy as np

# %%
T_test = pd.read_csv(r'C:\Users\Jagat\Downloads\test.csv')
T_train = pd.read_csv(r'C:\Users\Jagat\Downloads\train.csv')

# %%
T_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train = T_train.copy()
train.drop(columns = ['Name'])
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
age_mean = t_train['Age'].mean()
train.fillna(value=age_mean, inplace=True)
train['Cabin'].unique()
# Out:
# array([39.245791245791246, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56',
#        'A6', 'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83',
#        'F33', 'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60',
#        'E101', 'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7',
#        'C49', 'F4', 'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78',
#        'D35', 'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7',
#        'A19', 'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train = train.astype({"Embarked": str})
train['Embarked']= le.fit_transform(train['Embarked'])
train['Sex']= le.fit_transform(train['Sex'])
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
del train['PassengerId']

train
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.000000      1      0   7.2500         3
# 1           1       1    0  38.000000      1      0  71.2833         1
# 2           1       3    0  26.000000      0      0   7.9250         3
# 3           1       1    0  35.000000      1      0  53.1000         3
# 4           0       3    1  35.000000      0      0   8.0500         3
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         3
# 887         1       1    0  19.000000      0      0  30.0000         3
# 888         0       3    0  39.245791      1      2  23.4500         3
# 889         1       1    1  26.000000      0      0  30.0000         1
# 890         0       3    1  32.000000      0      0   7.7500         2
#
# [891 rows x 8 columns]

# %%
y_train = train['Survived']
x_train = train[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
test = T_test.copy()
Age_mean = T_test['Age'].mean()
test.fillna(value=Age_mean, inplace=True)
la = LabelEncoder()
test = test.astype({"Embarked": str})
test['Embarked']= la.fit_transform(test['Embarked'])
test['Sex']= la.fit_transform(test['Sex'])
del test['Name']
del test['PassengerId']
del test['Ticket']
del test['Cabin']

x_test = test[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]

# %%
x_test
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0         3    1  34.50000      0      0    7.8292         1
# 1         3    0  47.00000      1      0    7.0000         2
# 2         2    1  62.00000      0      0    9.6875         1
# 3         3    1  27.00000      0      0    8.6625         2
# 4         3    0  22.00000      1      1   12.2875         2
# ..      ...  ...       ...    ...    ...       ...       ...
# 413       3    1  30.27259      0      0    8.0500         2
# 414       1    0  39.00000      0      0  108.9000         0
# 415       3    1  38.50000      0      0    7.2500         2
# 416       3    1  30.27259      0      0    8.0500         2
# 417       3    1  30.27259      1      1   22.3583         0
#
# [418 rows x 7 columns]

# %%
y_pred = classifier.predict(x_test)

# %%
Copy = T_test['PassengerId']
sub = Copy.copy()
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
surv = pd.DataFrame(y_pred, columns = ['Survived'])
sub = surv.assign(PassengerId = T_test['PassengerId'])
sub = sub.reindex(columns=['PassengerId','Survived'])
sub
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
sub.to_csv('titanic_sub.csv')
